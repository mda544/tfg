# %%
import pandas as pd

# %%
filename = u'./cable_db.csv'

cable_db = pd.read_csv( filename, decimal=',', sep=';')

# %%
cable_db
# Out:
#                    Cstring      D  TLO  THI  TCDRMAX      RLO      RHI  EMISS  \
# 0  400 mm2 DRAKE 26/7 ACSR  28.12   25   75      100  0.07284  0.08689    0.5
#
#    ABSORP  HNH  HEATOUT  HEATCORE
# 0     0.5    3   1139.5     351.7

# %%
cableid = u'400 mm2 DRAKE 26/7 ACSR'
#cableid = u'cc'

cablex = cable_db[ cable_db[ 'Cstring'] == cableid]

print(cablex)

print( len(cablex))
# Out:
#                    Cstring      D  TLO  THI  TCDRMAX      RLO      RHI  EMISS  \
# 0  400 mm2 DRAKE 26/7 ACSR  28.12   25   75      100  0.07284  0.08689    0.5
#
#    ABSORP  HNH  HEATOUT  HEATCORE
# 0     0.5    3   1139.5     351.7
# 1
